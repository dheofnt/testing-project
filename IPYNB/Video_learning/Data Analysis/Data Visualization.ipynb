# %% [markdown]
# # 1. HISTOGRAM

# %% [markdown]
# # Creating Histogram Using Matplotlib

# %%
# IMPORT
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.hist(tips['total_bill'])
plt.title('Total Bill Histogram', size = 19)
plt.xlabel('Total Bill')
plt.ylabel('Frequency')

plt.show()

# %%
plt.style.use('seaborn')
plt.figure(figsize = (8,6))
plt.hist(tips['total_bill'], 10, color = 'red')
plt.title('Total Bill Histogram', size = 15)
plt.xlabel('Total Bill', size = 10)
plt.ylabel('Frequency', size = 10)
plt.grid(True)
plt.legend(['Total Bill from Customer'], loc = 0)
plt.savefig('TotalBill_Histogram.png')
plt.show()

# %% [markdown]
# # Creating Histogram Using Seaborn

# %%
sns.distplot(tips['tip'])
plt.title('Tip Histogram', size = 20)
plt.show()
# Out:
# C:\Users\dheof\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(tips['tip'])
plt.title('Tip Histogram', size = 20)
plt.show()

# %%
sns.histplot(tips['tip'])
plt.title('Tip Histogram', size = 20)
plt.show()

# %% [markdown]
# # Creating Histogram Using Seaborn

# %%
tips['tip'].hist(color = 'red', alpha = 0.4)
plt.title('Tip Histogram', size = 20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2. BOX PLOT

# %% [markdown]
# # Create Boxplot Using Matplotlib

# %%
# IMPORT
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.style.use('seaborn')
plt.figure(figsize = (8,6))
plt.boxplot(tips['total_bill'])
plt.title('Total Bill Boxplot', size = 15)
plt.xlabel('Total Bill')
plt.ylabel('Value')
plt.savefig('TotalBill_Boxplot.png')
plt.show()

# %% [markdown]
# # Create Boxplot Using Seaborn

# %%
sns.boxplot(x = tips['tip'])
plt.title('Tips Boxplot', size = 20)
plt.show()

# %%
sns.boxplot(x = tips['tip'], y = tips['day'])
plt.title('Tip Boxplot', size = 20)
plt.show()

# %% [markdown]
# # Create Boxplot Using Pandas

# %%
tips.boxplot(column = 'tip')
plt.title('Tip Boxplot', size = 20)
plt.show()

# %% [markdown]
# # 3. Lineplot

# %% [markdown]
# # Create Lineplot Using Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
plt.figure(figsize = (8,6))
plt.plot(flights[flights['month']=='Jan']['year'],
        flights[flights['month']=='Jan']['passengers'],
        'green')
plt.title('Number of Passenggers in January Yearly', size = 17)
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.show()

# %%
x1 = flights['year'][flights['month']=='Jan']
y1 = flights['passengers'][flights['month']=='Jan']
x2 = flights['year'][flights['month']=='Dec']
y2 = flights['passengers'][flights['month']=='Dec']

plt.style.use('seaborn')
plt.figure(figsize = (8,6))
plt.plot(x1, y1, 'red',
        x2, y2, 'blue')
plt.title('Numbers of Passengers in January & December Yearly', size = 15)
plt.xlabel('Yearly')
plt.ylabel('Number of Passengers')
plt.grid(True)
plt.legend(['January Passengers', 'December Passengers'])
plt.savefig('JanDes_Passengers_LinePlot.png')
plt.show()

# %% [markdown]
# # Create Lineplot Using Seaborn

# %%
sns.lineplot(data=flights, x = 'year', y = 'passengers', hue = 'month')
plt.title('Number of Passengers Every Month', size = 20)
plt.show()

# %% [markdown]
# # Create Lineplot Using Pandas

# %%
df_january = flights[flights['month'] == 'Jan']
df_january.plot.line(x = 'year', y = 'passengers')
plt.title('Number of Passengers in January', size = 20)
plt.show()

# %% [markdown]
# # 4. Scatterplot

# %% [markdown]
# # Create Scatterplot Using Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize = (9,7))
plt.scatter(tips['total_bill'], tips['tip'])
plt.title('Scatter Plot: Total Bill vs Tip', size = 15)
plt.xlabel('Total_Bill')
plt.ylabel('Tip')
plt.show()

# %%
plt.style.use('seaborn')
plt.figure(figsize = (9,7))
plt.scatter(tips['size'], tips['tip'])
plt.title('Scatter Plot: Size vs Tip', size = 15)
plt.xlabel('Size')
plt.ylabel('Tip')
plt.grid(True)
plt.savefig('Scatterplot_SizeTip.png')
plt.show()

# %% [markdown]
# # Create Scatterplot Using Seaborn

# %%
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', hue = 'day', style = 'time')
plt.title('Scatter Plot: Total Bill vs Tip', size = 15)
plt.show()

# %% [markdown]
# # Create Scatterplot Using Pandas

# %%
tips.plot.scatter(x = 'total_bill', y = 'tip')
plt.title('Scatter Plot: Total Bill vs Tip', size = 15)
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# # 5. Bar Plot

# %% [markdown]
# # Create Bar Plot Using Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_by_data = tips[['tip', 'day']].groupby(['day']).mean()
tips_by_data
# Out:
#            tip
# day
# Thur  2.771452
# Fri   2.734737
# Sat   2.993103
# Sun   3.255132

# %%
x = tips['day'].unique().tolist()
y = tips_by_data['tip']

plt.figure(figsize = (8,6))
plt.bar(x, y, color = ['blue', 'red', 'green', 'yellow'])
plt.title('Barplot: Average Tips Everyday', size = 15)
plt.xlabel('Days')
plt.ylabel('Tip')
plt.show()

# %%
x = tips['day'].unique().tolist()
y = tips_by_data['tip']

plt.figure(figsize = (8,6))
plt.barh(x, y, color = ['blue', 'red', 'green', 'yellow'])
plt.title('Barplot: Average Tips Everyday', size = 15)
plt.xlabel('Days')
plt.ylabel('Tip')
plt.savefig('Barplot_AVG_Tips.png')
plt.show()

# %% [markdown]
# # Create Barplot Using Seaborn

# %%
sns.barplot(data=tips, x = 'day', y = 'tip')
plt.title('Barplot: Average Tips Everyday', size = 15)
plt.xlabel('Day')
plt.ylabel()
plt.show()

# %%
sns.barplot(data=tips, x = 'day', y = 'tip', hue = 'sex')
plt.title('Barplot: Average Tips Everyday', size = 15)
plt.legend(loc = 0)
plt.show()

# %%
sns.barplot(data=tips, y = 'day', x = 'tip', hue = 'sex')

plt.title('Barplot: Average Tips Everyday', size = 15)
plt.legend(loc = 0)
plt.show()

# %%
import numpy as np

sns.barplot(data = tips, x = 'tip', y = 'day', estimator = np.median)
plt.title('Barplot: Median Tips Everyday', size = 15)
plt.show
# Out:
# Text(0.5, 1.0, 'Barplot: Median Tips Everyday')

# %% [markdown]
# # Create Bar Plot Using Pandas

# %%
tips_by_day = tips[['tip', 'day']].groupby(['day'], as_index=False).mean()
tips_by_day
# Out:
#     day       tip
# 0  Thur  2.771452
# 1   Fri  2.734737
# 2   Sat  2.993103
# 3   Sun  3.255132

# %%
tips_by_day.plot.bar(x='day', y='tip')
plt.title('Tip by Day', size=15)
plt.show()

# %% [markdown]
# # 6. Pie chart

# %% [markdown]
# # Create Pie Chart Using Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_by_day = tips[['tip', 'day']].groupby(['day'], as_index=False).mean()
tips_by_day
# Out:
#     day       tip
# 0  Thur  2.771452
# 1   Fri  2.734737
# 2   Sat  2.993103
# 3   Sun  3.255132

# %%
plt.figure(figsize = (8,6))
plt.pie(tips_by_day['tip'], 
        labels=tips_by_day['day'],
       autopct = '%.2f',
        explode = (0, 0.2, 0, 0.1)
       )

plt.axis('equal')
plt.title('Pie Chart: Average Tips Everyday', size = 15)
plt.show()

# %% [markdown]
# # Create Pie Chart Using Pandas

# %%
tips_by_day.plot.pie(y = 'tip',
                    figsize = (8,6),
                    autopct = '%.2f',
                    explode = (0, 0.2, 0, 0.1)
                    )
plt.axis('equal')
plt.title('Pie Chart: Average Tips Everyday', size = 15)
# Out:
# Text(0.5, 1.0, 'Pie Chart: Average Tips Everyday')

# %% [markdown]
# # 7. HEATMAP

# %% [markdown]
# # Create Heatmap Using Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
correlation_matrix = tips[['total_bill', 'tip', 'size']].corr()
correlation_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.pcolor(correlation_matrix, cmap='RdYlGn')
plt.show()

# %% [markdown]
# # Create Heatmap Using Seaborn

# %%
plt.figure(figsize = (8,6))
sns.heatmap(correlation_matrix, annot = True, cmap = 'RdYlGn')
plt.show()

# %% [markdown]
# # 8. Folium

# %% [markdown]
# # Create Geographical Map Using Folium

# %%
import pandas as pd
import folium

# %% [markdown]
# # World Map

# %%
world_map = folium.Map()
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Jakarta Map

# %%
jakarta_map = folium.Map(location = [-6.2088, 106.8456], zoom_start = 8)
jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
jakarta_map = folium.Map(location = [-6.2088, 106.8456], zoom_start = 12)
jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Surabaya Map: Stamen Toner Map

# %%
surabaya_map = folium.Map(location = [-7.2575, 112.7521],
                         zoom_start = 12,
                         tiles = 'Stamen Toner'
                         )
surabaya_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Bandung Map: Stamen Terrain Map

# %%
bandung_map = folium.Map(
    location = [-6.9175, 107.6191],
    zoom_start = 12,
    tiles = 'Stamen Terrain'
)

bandung_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Marker

# %%
# Jakarta Map
jakarta_map = folium.Map(
    location = [-6.2088, 106.8456],
    zoom_start = 12
)

# Marker
# Monas
folium.Marker([-6.175392, 106.827153],
             popup = '<i>Monas<i>',
             tooltip = 'Ini Monumen Nasional'
             ).add_to(jakarta_map)

# Kota Tua Jakarta
folium.Marker([-6.1376, 106.8171],
             popup = 'Kota Tua Jakarta',
             tooltip = 'Mari ke Kota Tua Jakarta',
             icon = folium.Icon(color = 'red', icon = 'info-sign')
             ).add_to(jakarta_map)

# Blok M
folium.CircleMarker([-6.2446, 106.8006],
                   radius = 30,
                   popup = 'Blok M',
                   tooltip = 'Pandemi selesai, mari kita bertemu di Blok M',
                   color = '#3186cc',
                   ).add_to(jakarta_map)

jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Choropleth Map

# %%
df = pd.read_csv(r'C:\Users\dheof\Downloads\data-jumlah-pelaporan-perpindahan-penduduk-keluar-provinsi-dki-jakarta-berdasarkan-jenis-kelamin-bulan-maret-tahun-2020.csv')
df.head()
# Out:
#    tahun  bulan         kota_kabupaten                 kecamatan  \
# 0   2020      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 1   2020      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 2   2020      3  ADM. KEPULAUAN SERIBU    KEPULAUAN SERIBU UTARA
# 3   2020      3  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
# 4   2020      3  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU SELATAN
#
#            kelurahan jenis_kelamin   jumlah
# 0     PULAU PANGGANG      Laki-Laki     3.0
# 1       PULAU KELAPA      Laki-Laki     1.0
# 2      PULAU HARAPAN      Laki-Laki     4.0
# 3  PULAU UNTUNG JAWA      Laki-Laki     1.0
# 4       PULAU TIDUNG      Laki-Laki     2.0

# %%
df_kel = df[['kelurahan', 'jumlah']]
df_kel
# Out:
#              kelurahan  jumlah
# 0       PULAU PANGGANG     3.0
# 1         PULAU KELAPA     1.0
# 2        PULAU HARAPAN     4.0
# 3    PULAU UNTUNG JAWA     1.0
# 4         PULAU TIDUNG     2.0
# ..                 ...     ...
# 529             MUNJUL    29.0
# 530               SETU    27.0
# 531         BAMBU APUS    22.0
# 532       LUBANG BUAYA    44.0
# 533              CEGER    17.0
#
# [534 rows x 2 columns]

# %%
# Jakarta geojson
jakarta = r'C:\Users\dheof\Downloads\jakarta_by_kelurahan_geo.geojson'
jkt_location = [-6.2088, 106.8456]

jkt_map = folium.Map(location = jkt_location, zoom_start = 12)

folium.Choropleth(geo_data = jakarta,
                 data = df_kel,
                  columns = ['kelurahan', 'jumlah'],
                  key_on = 'feature.propeties.name',
                  fill_color = 'YlOrRd',
                  fill_opacity = 0.7,
                  line_opacity = 0.2,
                  legend_name = 'Transmigrant Rate in Jakarta'
                 ).add_to(jkt_map)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-b55c87673810> in <module>
#       5 jkt_map = folium.Map(location = jkt_location, zoom_start = 12)
#       6
# ----> 7 folium.Choropleth(geo_data = jakarta,
#       8                  data = df_kel,
#       9                   columns = ['kelurahan', 'jumlah'],
#
# ~\anaconda3\lib\site-packages\folium\features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1287                 smooth_factor=smooth_factor)
#    1288         else:
# -> 1289             self.geojson = GeoJson(
#    1290                 geo_data,
#    1291                 style_function=style_function,
#
# ...

# %%
import json
import geopandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-17b59ddc0f11> in <module>
#       1 import json
# ----> 2 import geopandas
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
import geopandas as gpd
earthquake = gpd.read_file('jakarta_by_kelurahan_geo.geojson')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-76-efb54bc3ba5a> in <module>
# ----> 1 import geopandas as gpd
#       2 earthquake = gpd.read_file('jakarta_by_kelurahan_geo.geojson')
#
# ModuleNotFoundError: No module named 'geopandas'

# %% [markdown]
# # ADVANCED DATA VISUALIZATION

# %% [markdown]
# # COHORT VISUALIZATION

# %%
import numpy as np
import pandas as pd
from datetime import datetime

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from operator import attrgetter

# %%
df = pd.read_csv(r'C:\Users\dheof\Downloads\Cohort Data Visualization\session_5_cohort_analysis.csv',
                dtype={'CustomerID': str,
                      'InvoiceID': str},
                parse_dates = ['InvoiceDate'])
df.head()
# Out:
#   InvoiceNo StockCode                Description  Quantity  \
# 0    539993     22386    JUMBO BAG PINK POLKADOT        10
# 1    539993     21499         BLUE POLKADOT WRAP        25
# 2    539993     21498        RED RETROSPOT WRAP         25
# 3    539993     22379   RECYCLING BAG RETROSPOT          5
# 4    539993     20718  RED RETROSPOT SHOPPER BAG        10
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2011-04-01 10:00:00       1.95      13313  United Kingdom
# 1 2011-04-01 10:00:00       0.42      13313  United Kingdom
# 2 2011-04-01 10:00:00       0.42      13313  United Kingdom
# 3 2011-04-01 10:00:00       2.10      13313  United Kingdom
# 4 2011-04-01 10:00:00       1.25      13313  United Kingdom

# %%
# 1. COHORT DATE: TANGGAL CUSTOMER MEMBELI ATAU MEMBUKA
2. CURRENT ACITIVITY DATE: AKTIVITAS KONSUMEN KETIKA MEMBUAT TRANSAKSI DLL
3. TOTAL DISTINCT SUBJECT
4. PERIOD DISTANCE

# %%
df["cohort_month"] = df.groupby("CustomerID")["InvoiceDate"].transform("min").dt.to_period("M")
df["current_order_month"] = df["InvoiceDate"].dt.to_period("M")
df.head()
# Out:
#   InvoiceNo StockCode                Description  Quantity  \
# 0    539993     22386    JUMBO BAG PINK POLKADOT        10
# 1    539993     21499         BLUE POLKADOT WRAP        25
# 2    539993     21498        RED RETROSPOT WRAP         25
# 3    539993     22379   RECYCLING BAG RETROSPOT          5
# 4    539993     20718  RED RETROSPOT SHOPPER BAG        10
#
#           InvoiceDate  UnitPrice CustomerID         Country cohort_month  \
# 0 2011-04-01 10:00:00       1.95      13313  United Kingdom      2011-04
# 1 2011-04-01 10:00:00       0.42      13313  United Kingdom      2011-04
# 2 2011-04-01 10:00:00       0.42      13313  United Kingdom      2011-04
# 3 2011-04-01 10:00:00       2.10      13313  United Kingdom      2011-04
# 4 2011-04-01 10:00:00       1.25      13313  United Kingdom      2011-04
#
#   current_order_month
# 0             2011-04
# 1             2011-04
# 2             2011-04
# 3             2011-04
# 4             2011-04

# %%
df_cohort = df.groupby(['cohort_month', 'current_order_month']) \
                    .agg(n_customer = ('CustomerID', 'nunique')) \
                    .reset_index(drop = False)
df_cohort.head()
# Out:
#   cohort_month current_order_month  n_customer
# 0      2011-01             2011-01         967
# 1      2011-01             2011-02         320
# 2      2011-01             2011-03         368
# 3      2011-01             2011-04         338
# 4      2011-01             2011-05         381

# %%
df_cohort['period_number'] = (df_cohort.current_order_month - df_cohort.cohort_month).apply(attrgetter('n'))
df_cohort.head()
# Out:
#   cohort_month current_order_month  n_customer  period_number
# 0      2011-01             2011-01         967              0
# 1      2011-01             2011-02         320              1
# 2      2011-01             2011-03         368              2
# 3      2011-01             2011-04         338              3
# 4      2011-01             2011-05         381              4

# %%
cohort_retention_pivot = df_cohort.pivot_table(index='cohort_month',
                                              columns = 'period_number',
                                              values = 'n_customer')
cohort_retention_pivot
# Out:
# period_number     0      1      2      3      4      5      6      7      8   \
# cohort_month
# 2011-01        967.0  320.0  368.0  338.0  381.0  397.0  396.0  341.0  417.0
# 2011-02        542.0  137.0  142.0  166.0  166.0  173.0  162.0  169.0  172.0
# 2011-03        500.0  109.0  121.0  123.0  129.0  113.0  120.0  137.0  144.0
# 2011-04        383.0   86.0   84.0   82.0   75.0   76.0  106.0   98.0   24.0
# 2011-05        309.0   61.0   64.0   54.0   77.0   58.0   88.0   23.0    NaN
# 2011-06        314.0   57.0   55.0   64.0   61.0   87.0   21.0    NaN    NaN
# 2011-07        252.0   50.0   47.0   53.0   66.0   10.0    NaN    NaN    NaN
# 2011-08        186.0   32.0   44.0   52.0   11.0    NaN    NaN    NaN    NaN
# 2011-09        255.0   40.0   55.0    7.0    NaN    NaN    NaN    NaN    NaN
# 2011-10        266.0   53.0   10.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-11        244.0   11.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
cohort_size = cohort_retention_pivot.iloc[:,0]
retention_in_percentage = cohort_retention_pivot.divide(cohort_size, axis = 0)
retention_in_percentage
# Out:
# period_number   0         1         2         3         4         5   \
# cohort_month
# 2011-01        1.0  0.330920  0.380558  0.349535  0.394002  0.410548
# 2011-02        1.0  0.252768  0.261993  0.306273  0.306273  0.319188
# 2011-03        1.0  0.218000  0.242000  0.246000  0.258000  0.226000
# 2011-04        1.0  0.224543  0.219321  0.214099  0.195822  0.198433
# 2011-05        1.0  0.197411  0.207120  0.174757  0.249191  0.187702
# 2011-06        1.0  0.181529  0.175159  0.203822  0.194268  0.277070
# 2011-07        1.0  0.198413  0.186508  0.210317  0.261905  0.039683
# 2011-08        1.0  0.172043  0.236559  0.279570  0.059140       NaN
# 2011-09        1.0  0.156863  0.215686  0.027451       NaN       NaN
# 2011-10        1.0  0.199248  0.037594       NaN       NaN       NaN
# 2011-11        1.0  0.045082       NaN       NaN       NaN       NaN
# 2011-12        1.0       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
grid_kws = {'height_ratios': (.9, .05), 'hspace': .3}
f, (ax, cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize = (12,8))

ax = sns.heatmap(retention_in_percentage,
                ax=ax,
                cbar_ax = cbar_ax,
                annot = True,
                fmt = '.2%',
                linewidths = .5,
                cbar_kws = {'orientation': 'horizontal'},
                cmap = 'YlGnBu')

ax.set_title('Monthly Customer Retention Cohort 2011', fontsize = 15)
ax.set_ylabel('Cohort Month', fontsize = 15)
ax.set_xlabel('Month Distance', fontsize = 15)
plt.show()

# %% [markdown]
# # COHORT ANALYSIS: DATA VISUALIZATION LINEPLOT

# %%
df_lineplot = df_cohort.copy()
df_lineplot.head()
# Out:
#   cohort_month current_order_month  n_customer  period_number
# 0      2011-01             2011-01         967              0
# 1      2011-01             2011-02         320              1
# 2      2011-01             2011-03         368              2
# 3      2011-01             2011-04         338              3
# 4      2011-01             2011-05         381              4

# %%
df_lineplot['cohort_month'] = df_lineplot['cohort_month'].astype(str)
df_lineplot['current_order_month'] = df_lineplot['current_order_month'].astype(str)

df_plot_state = df_lineplot.groupby(['cohort_month']).agg({'n_customer': 'max'})
df_plot = df_lineplot.set_index(['cohort_month']).div(df_plot_state, level = 'cohort_month') * 100
df_plot = df_plot.reset_index()[['cohort_month', 'n_customer']].rename(columns = {'n_customer': 'percentage_customer'})
df_plot.head()

df_plot['current_order_month'] = df_lineplot['current_order_month']
df_plot['period_number'] = df_lineplot['period_number']
df_plot = df_plot[['cohort_month', 'current_order_month', 'percentage_customer', 'period_number']]
df_plot.head()
# Out:
#   cohort_month current_order_month  percentage_customer  period_number
# 0      2011-01             2011-01           100.000000              0
# 1      2011-01             2011-02            33.092037              1
# 2      2011-01             2011-03            38.055843              2
# 3      2011-01             2011-04            34.953464              3
# 4      2011-01             2011-05            39.400207              4

# %%
plt.figure(figsize = (12,8))
ax = sns.lineplot(x = 'period_number',
                 y = 'percentage_customer',
                 hue = 'cohort_month',
                 dashes = True,
                 linewidth = 2,
                 data = df_plot,
                 palette = 'husl'
                 )
ax.set_title('Monthly Customer Retention Cohort 2011', fontsize = 15)
ax.set_ylabel('Proportion User (%)', fontsize = 15)
ax.set_xlabel('Month Distance', fontsize = 15)

top_3 = df_plot[df_plot['period_number']==1].sort_values('percentage_customer', ascending = False).iloc[:3]
top_3_name = top_3['cohort_month'].tolist()
top_3_value = [round(x,2) for x in top_3['percentage_customer'].tolist()]

text_plot = f'''
The Highest of First Month Retention
Date {top_3_name[0]} = {top_3_value[0]}%
Date {top_3_name[1]} = {top_3_value[1]}%
Date {top_3_name[2]} = {top_3_value[2]}%
'''
plt.axvline(x = 1, linestyle = '--', color = 'black', lw = 2, alpha = .5)
plt.text(1.05, 80, text_plot, fontsize = 13)
plt.show()

# %% [markdown]
# # Advanced Data Visualization

# %%
import numpy as np
import pandas as pd
from datetime import datetime

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## 1. Import Data

# %%
df = pd.read_csv(r'C:\Users\dheof\Downloads\Topic 11 - Advanced Data Visualization using Plotly\data_titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 2. Plotly Visualization

# %% [markdown]
# ## A. Pie CHart

# %%
# Create grouped survival data
df_survival = df.groupby(['Survived']).count()['PassengerId'].reset_index()
df_survival['Survived'] = df_survival['Survived'].map(lambda x: 'Yes' if x == 1 else 'No')
df_survival
# Out:
#   Survived  PassengerId
# 0       No          549
# 1      Yes          342

# %%
# Create grouped gender data
df_gender = df.groupby(['Sex']).count()['PassengerId'].reset_index()
df_gender
# Out:
#       Sex  PassengerId
# 0  female          314
# 1    male          577

# %%
# Plotly Express
# init_notebook_mode
fig = px.pie(df_survival,
            names = 'Survived',
            values = 'PassengerId',
            title = 'Percentage of Passenger Survival')
fig.show()
# Out:
# <div>                            <div id="521891dd-a4fe-4a17-9d26-6ead36ea3554" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("521891dd-a4fe-4a17-9d26-6ead36ea3554")) {                    Plotly.newPlot(                        "521891dd-a4fe-4a17-9d26-6ead36ea3554",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Survived=%{label}<br>PassengerId=%{value}<extra></extra>","labels":["No","Yes"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[549,342]}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"
# ...

# %%
# Graphic Objects Plotly (Simple)
# Create subplot with 1 row and 2 columns
# in matplotlib, this is similiar with plt.subplots(1, 2)
fig = make_subplots(rows = 1,
                   cols = 2,
                   specs= [[{'type': 'domain'}, {'type': 'domain'}]])

# Create first pie plot about survival data in coords (1,1)
fig.add_trace(go.Pie(labels = df_survival['Survived'],
                    values = df_survival['PassengerId'],
                    title = 'Percentage of Passenger Survival',
                    name = 'Survive?',
                    marker = {'colors': ['Red', 'LightSkyBlue']}),
             1, 1)

# Create second pie plot about gender data in coords (1, 2)
fig.add_trace(go.Pie(labels = df_gender['Sex'],
                    values = df_gender['PassengerId'],
                    title = 'Percentage Gender of Passenger',
                    name = 'Gender',
                    marker = {'colors': ['Blue', 'Green']}),
             1, 2)
fig.show()
# Out:
# <div>                            <div id="c46d7d9f-63f3-4a16-a1e9-a0831d71b8fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c46d7d9f-63f3-4a16-a1e9-a0831d71b8fd")) {                    Plotly.newPlot(                        "c46d7d9f-63f3-4a16-a1e9-a0831d71b8fd",                        [{"domain":{"x":[0.0,0.45],"y":[0.0,1.0]},"labels":["No","Yes"],"marker":{"colors":["Red","LightSkyBlue"]},"name":"Survive?","title":{"text":"Percentage of Passenger Survival"},"type":"pie","values":[549,342]},{"domain":{"x":[0.55,1.0],"y":[0.0,1.0]},"labels":["female","male"],"marker":{"colors":["Blue","Green"]},"name":"Gender","title":{"text":"Percentage Gender of Passenger"},"type":"pie","values":[314,577]}],                        {"template":{"data":{"bar":[{
# ...

# %%
# Graphic Objects Plotly (Advanced)
# Create subplot with 1 row and 2 columns
# in matplotlib, this is similar with plt.subplots(1, 2)
fig = go.Figure()

# Create first pie plot about survival data in coords (1,1)
fig.add_trace(go.Pie(labels = df_survival["Survived"], 
                     values = df_survival["PassengerId"], 
                     name  = "Survive?",
                     marker= {'colors': ["Red","LightSkyBlue"]}),
              )

# ==============================================================
# Lets make up our pie chart, harnessing the go shapes and texts
# ==============================================================

# 1. Add hole in the center
fig.update_traces(hole=0.7, hoverinfo="label+percent+name")

# 2. Add 5 text based on certain coordinates
fig.update_layout(
    title_text="Number of Passenger based on Survival Status",
    showlegend=False,
    annotations=[dict(text="Total Passenger", x=0.17+0.33, y=0.65, font_size=15, showarrow=False),
                 dict(text=str(df_survival["PassengerId"].sum()), x=0.190+0.31, y=0.55, font_size=40, showarrow=False),
                 dict(text="Y", x=0.481, y=0.425, font_size=15, showarrow=False),
                 dict(text="N", x=0.481+0.06, y=0.425, font_size=15, showarrow=False),
                ])

# 3. Add two additional boxes
## First Box (Blue Color)
fig.add_shape(type="rect",
    x0=0.1+0.35,
    y0=0.40, 
    x1=0.2+0.27, 
    y1=0.45,
    line=dict(
        color="Black",
        width=2,
    ),
    fillcolor="LightSkyBlue",
)

## Second Box (Red Color)
fig.add_shape(type="rect",
    x0=0.18+0.06+0.27, 
    y0=0.40, 
    x1=0.2+0.06+0.27, 
    y1=0.45,
    line=dict(
        color="Black",
        width=2,
    ),
    fillcolor="Red",
)

# Show the result
fig.show()
# plotly.offline.plot(fig, filename = 'plot.html')
# Out:
# <div>                            <div id="12b59c23-c805-45ec-8262-4d4fb40e107f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12b59c23-c805-45ec-8262-4d4fb40e107f")) {                    Plotly.newPlot(                        "12b59c23-c805-45ec-8262-4d4fb40e107f",                        [{"hole":0.7,"hoverinfo":"label+percent+name","labels":["No","Yes"],"marker":{"colors":["Red","LightSkyBlue"]},"name":"Survive?","type":"pie","values":[549,342]}],                        {"annotations":[{"font":{"size":15},"showarrow":false,"text":"Total Passenger","x":0.5,"y":0.65},{"font":{"size":40},"showarrow":false,"text":"891","x":0.5,"y":0.55},{"font":{"size":15},"showarrow":false,"text":"Y","x":0.481,"y":0.425},{"font":{"size":15},"showarrow":false,"text":
# ...

# %% [markdown]
# ### About the coordinates of X and Y, there is no exact formula to determine x0 and y0 in the graphic objects. Its just a simple trial and error to determine the value itself. If it doens't fit in your graph, so you can change the number manually until it is becoming tidy.###

# %% [markdown]
# ## B. Barchart

# %%
df_class = df.groupby(["Pclass"])["PassengerId"].count().reset_index()
df_class
# Out:
#    Pclass  PassengerId
# 0       1          216
# 1       2          184
# 2       3          491

# %%
# Plotly Express
fig = px.bar(df_class,
             x = "Pclass", 
             y= "PassengerId",
             title = "Percentage of Passenger Survival")
fig.show()
# plotly.offline.plot(fig, filename = 'plot.html')
# Out:
# <div>                            <div id="c28447b8-c31c-425e-8bae-86c50a8d602a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c28447b8-c31c-425e-8bae-86c50a8d602a")) {                    Plotly.newPlot(                        "c28447b8-c31c-425e-8bae-86c50a8d602a",                        [{"alignmentgroup":"True","hovertemplate":"Pclass=%{x}<br>PassengerId=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":[1,2,3],"xaxis":"x","y":[216,184,491],"yaxis":"y"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"
# ...

# %%
# Graphic Objects Plotly (Simple)
# Create subplot with 1 row and 2 columns
# in matplotlib, this is similar with plt.subplots(1, 2)
fig = make_subplots(rows=1, 
                    cols=2, 
                    specs=[[{'type':'bar'}, {'type':'bar'}]])

# Create male and female data
df_class_male = df.query("""Sex == 'male'""").groupby(["Pclass"])["PassengerId"].count().reset_index()
df_class_female = df.query("""Sex != 'male'""").groupby(["Pclass"])["PassengerId"].count().reset_index()


# Create first pie plot about survival data in coords (1,1)
fig.add_trace(go.Bar(x = df_class_male["Pclass"], 
                     y = df_class_male["PassengerId"],
                     orientation='v',
                     name="Male",
                     hoverinfo="all"),
              1, 1)

# Create second pie plot about gender data in coords (1,2)
fig.add_trace(go.Bar(x = df_class_female["Pclass"], 
                     y = df_class_female["PassengerId"],
                     orientation='v',
                     name="Female",
                     hoverinfo="all"),
              1, 2)
fig.show()
# Out:
# <div>                            <div id="1575d1b4-274e-498d-9b96-cc16eff538bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1575d1b4-274e-498d-9b96-cc16eff538bc")) {                    Plotly.newPlot(                        "1575d1b4-274e-498d-9b96-cc16eff538bc",                        [{"hoverinfo":"all","name":"Male","orientation":"v","type":"bar","x":[1,2,3],"xaxis":"x","y":[122,108,347],"yaxis":"y"},{"hoverinfo":"all","name":"Female","orientation":"v","type":"bar","x":[1,2,3],"xaxis":"x2","y":[94,76,144],"yaxis":"y2"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type
# ...

# %%
# Graphic Objects Plotly (Stacked Bar Chart)
fig = go.Figure()
# Create first pie plot about survival data in coords
fig.add_trace(go.Bar(y = df_class_male["Pclass"], 
                     x = df_class_male["PassengerId"],
                     orientation='h',
                     name="Male",
                     hoverinfo="all"),)

# Create second pie plot about gender data in coords
fig.add_trace(go.Bar(y = df_class_female["Pclass"], 
                     x = df_class_female["PassengerId"],
                     orientation='h',
                     name="Female",
                     hoverinfo="all"),)
# Add barmode = stack
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>                            <div id="06082732-3f44-4f25-af0b-1941c4988ed0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06082732-3f44-4f25-af0b-1941c4988ed0")) {                    Plotly.newPlot(                        "06082732-3f44-4f25-af0b-1941c4988ed0",                        [{"hoverinfo":"all","name":"Male","orientation":"h","type":"bar","x":[122,108,347],"y":[1,2,3]},{"hoverinfo":"all","name":"Female","orientation":"h","type":"bar","x":[94,76,144],"y":[1,2,3]}],                        {"barmode":"stack","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":
# ...

# %%
# Graphic Objects Plotly (Advanced Barchart)

# Create text label
top_labels = ['Strongly agree', 'Agree', 'Neutral', 'Disagree',
              'Strongly disagree']
# Define labels
colors = ['rgba(38, 24, 74, 0.8)', 'rgba(71, 58, 131, 0.8)',
          'rgba(122, 120, 168, 0.8)', 'rgba(164, 163, 204, 0.85)',
          'rgba(190, 192, 213, 1)']

# Create matrix for survey data (The sum of each vector must be 100 (Percentage))
x_data = [[21, 30, 21, 16, 12],
          [24, 31, 19, 15, 11],
          [27, 26, 23, 11, 13],
          [29, 24, 15, 18, 14]]

# Define y label axis
y_data = ['The course was effectively<br>organized',
          'The course developed my<br>abilities and skills ' +
          'for<br>the subject', 'The course developed ' +
          'my<br>ability to think critically about<br>the subject',
          'I would recommend this<br>course to a friend']

fig = go.Figure()

# Create base Barplot for each vector
for i in range(0, len(x_data[0])):
    for xd, yd in zip(x_data, y_data):
        fig.add_trace(go.Bar(
            x=[xd[i]], y=[yd],
            orientation='h',
            marker=dict(
                color=colors[i],
                line=dict(color='rgb(248, 248, 249)', width=1)
            )
        ))
        
# Add update layout to beautify the visualization
fig.update_layout(
    xaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
        domain=[0.15, 1]
    ),
    yaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
    ),
    barmode='stack',
    paper_bgcolor='rgb(248, 248, 255)',
    plot_bgcolor='rgb(248, 248, 255)',
    margin=dict(l=120, r=10, t=140, b=80),
    showlegend=False,
)

# Add label text
annotations = []
for yd, xd in zip(y_data, x_data):
    # labeling the y-axis
    annotations.append(dict(xref='paper', yref='y',
                            x=0.14, y=yd,
                            xanchor='right',
                            text=str(yd),
                            font=dict(family='Arial', size=14,
                                      color='rgb(67, 67, 67)'),
                            showarrow=False, align='right'))
    # labeling the first percentage of each bar (x_axis)
    annotations.append(dict(xref='x', yref='y',
                            x=xd[0] / 2, y=yd,
                            text=str(xd[0]) + '%',
                            font=dict(family='Arial', size=14,
                                      color='rgb(248, 248, 255)'),
                            showarrow=False))
    # labeling the first Likert scale (on the top)
    if yd == y_data[-1]:
        annotations.append(dict(xref='x', yref='paper',
                                x=xd[0] / 2, y=1.1,
                                text=top_labels[0],
                                font=dict(family='Arial', size=14,
                                          color='rgb(67, 67, 67)'),
                                showarrow=False))
    space = xd[0]
    for i in range(1, len(xd)):
            # labeling the rest of percentages for each bar (x_axis)
            annotations.append(dict(xref='x', yref='y',
                                    x=space + (xd[i]/2), y=yd,
                                    text=str(xd[i]) + '%',
                                    font=dict(family='Arial', size=14,
                                              color='rgb(248, 248, 255)'),
                                    showarrow=False))
            # labeling the Likert scale
            if yd == y_data[-1]:
                annotations.append(dict(xref='x', yref='paper',
                                        x=space + (xd[i]/2), y=1.1,
                                        text=top_labels[i],
                                        font=dict(family='Arial', size=14,
                                                  color='rgb(67, 67, 67)'),
                                        showarrow=False))
            space += xd[i]

fig.update_layout(annotations=annotations)

fig.show()
# Out:
# <div>                            <div id="90e0e1ee-fd43-4c2a-8199-b0546c625d55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90e0e1ee-fd43-4c2a-8199-b0546c625d55")) {                    Plotly.newPlot(                        "90e0e1ee-fd43-4c2a-8199-b0546c625d55",                        [{"marker":{"color":"rgba(38, 24, 74, 0.8)","line":{"color":"rgb(248, 248, 249)","width":1}},"orientation":"h","type":"bar","x":[21],"y":["The course was effectively<br>organized"]},{"marker":{"color":"rgba(38, 24, 74, 0.8)","line":{"color":"rgb(248, 248, 249)","width":1}},"orientation":"h","type":"bar","x":[24],"y":["The course developed my<br>abilities and skills for<br>the subject"]},{"marker":{"color":"rgba(38, 24, 74, 0.8)","line":{"color":"rgb(248, 248, 249)
# ...

# %% [markdown]
# ### It is a full iterative session, such drawing a empty canvas. First you make one picture, then you add some properties, then you tune up the colors, and so on and so forth. At the end, you will get the beaufitul visualization that is built by python - plotly.

# %% [markdown]
# ## C. Demographic Bar Plot

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# We create age group based on the desired distances
df["age_group"] = df["Age"].map(lambda x: "0 - 10"  if 0<=x<=10 else\
                                          "11 - 20" if 11<=x<=20 else\
                                          "21 - 30" if 21<=x<=30 else\
                                          "31 - 40" if 31<=x<=40 else\
                                          "41 - 50" if 41<=x<=50 else\
                                          ">=51")
# Store the group name into a list
age_group_list = ["0 - 10", "11 - 20", "21 - 30", "31 - 40", "41 - 50", ">=51"]
# Let see the distribution
df.groupby(["age_group"])["PassengerId"].count()
# Out:
# age_group
# 0 - 10      64
# 11 - 20    115
# 21 - 30    229
# 31 - 40    153
# 41 - 50     84
# >=51       246
# Name: PassengerId, dtype: int64

# %%
# Then we create another group by using Gender
df_demographic = df.groupby(["Sex","age_group"])["PassengerId"].count().reset_index()
df_demographic = df_demographic.sort_values(["Sex","age_group"],ascending=[False,False]).reset_index(drop=True)
df_demographic
# Out:
#        Sex age_group  PassengerId
# 0     male      >=51          175
# 1     male   41 - 50           53
# 2     male   31 - 40           99
# 3     male   21 - 30          148
# 4     male   11 - 20           69
# 5     male    0 - 10           33
# 6   female      >=51           71
# 7   female   41 - 50           31
# 8   female   31 - 40           54
# 9   female   21 - 30           81
# 10  female   11 - 20           46
# 11  female    0 - 10           31

# %%
# Now lets make the demographic plot
# Demographic plot is basically a stacked bar chart, however the middle point is 0 (value)
# The strategy is: Create 2 bar charts,the first 1 must be negative, the second one positive in the same axis (y)

# 1. Separate female and female data in order to extract their passenger number by age groups
df_demographic_female = df_demographic.query("Sex!='male'").set_index(["age_group"])
df_demographic_male = df_demographic.query("Sex=='male'").set_index(["age_group"])

# 2a. Extract female passenger Id Data, then make it negative (-1), since we want to show the female color in left side
female_bins = np.array(df_demographic_female["PassengerId"].tolist())*-1
# 2b. While the male passenger is positive number
men_bins = np.array(df_demographic_male["PassengerId"].astype(int).tolist())

# 3. Store the maximum value, and the distance range in plot
max_value = df_demographic["PassengerId"].max()
jump = round(df_demographic["PassengerId"].max()/3)

# 4. Create the layout
layout = go.Layout(yaxis=go.layout.YAxis(title='Age Group',
                                         ticktext=df_demographic["age_group"].unique()
                                        ),
                   xaxis=go.layout.XAxis(
                           range   = [-max_value, max_value],
                           tickvals=[-max_value, -max_value+jump, -max_value+jump*2, 0 , max_value-jump*2, max_value-jump, max_value],
                           ticktext=[max_value,   max_value-jump, max_value-jump*2 , 0 , max_value-jump*2,  max_value-jump, max_value],
                           title='Number of Passengers'),
                   barmode='overlay',
                   bargap=0.1,
                   title="Titanic Passenger based on Age Group and Gender")

# 5. Create the figure
fig = go.Figure(layout=layout)

# 6a. Create barplot for Male
fig.add_trace(go.Bar(  y = age_group_list,
                       x = men_bins,
                       orientation='h',
                       name='Male',
                       hoverinfo='x',
                       marker=dict(color='seagreen')
                       ))
# 6b. Create barplot for Female
fig.add_trace(go.Bar(  y = age_group_list,
                       x = female_bins,
                       orientation='h',
                       name='Female',
                       text=1 * female_bins.astype('int'),
                       hoverinfo='x',
                       marker=dict(color='pink')
                       ))
# 7. Show the result
fig.show()
# Out:
# <div>                            <div id="1ba5029b-7e6d-463a-bf9f-e22f14df6187" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ba5029b-7e6d-463a-bf9f-e22f14df6187")) {                    Plotly.newPlot(                        "1ba5029b-7e6d-463a-bf9f-e22f14df6187",                        [{"hoverinfo":"x","marker":{"color":"seagreen"},"name":"Male","orientation":"h","type":"bar","x":[175,53,99,148,69,33],"y":["0 - 10","11 - 20","21 - 30","31 - 40","41 - 50",">=51"]},{"hoverinfo":"x","marker":{"color":"pink"},"name":"Female","orientation":"h","text":[-71.0,-31.0,-54.0,-81.0,-46.0,-31.0],"type":"bar","x":[-71,-31,-54,-81,-46,-31],"y":["0 - 10","11 - 20","21 - 30","31 - 40","41 - 50",">=51"]}],                        {"bargap":0.1,"barmode":"overlay"
# ...

# %% [markdown]
# ## D. Waterfall Plot

# %%
df_waterfall = pd.read_csv(r"C:\Users\dheof\Downloads\Topic 11 - Advanced Data Visualization using Plotly\session_5_vis_plotly_waterfall.csv")
df_waterfall
# Out:
#     hiring_year  resign_year  total_hired  total_resign  total_people  changes
# 0          2006            0          1.0           0.0           1.0      1.0
# 1          2007            0          2.0           0.0           3.0      2.0
# 2          2008            0          2.0           0.0           5.0      2.0
# 3          2009            0          7.0           0.0          12.0      7.0
# 4          2010            0          8.0           0.0          20.0      8.0
# 5          2011            0         76.0           0.0          96.0     76.0
# 6          2012         2012         41.0           1.0         136.0     40.0
# 7          2013         2013         43.0           3.0         177.0     40.0
# 8          2014         2014         56.0           6.0         230.0     50.0
# 9          2015         2015         31.0          13.0         254.0     18.0
# 10         2016         2016         14.0          12.0         269.0      2.0
# ...

# %%
# 1. Create the layout
layout = go.Layout(
    title= "Annual Employee Number Changes (2006 - 2020)",
    showlegend=False,
    yaxis=dict(title='Number of Employee'),
    xaxis=dict(title='Years')
    
)

# 2. Calculate the latest number of employee
all_employees = int(df_waterfall["total_hired"].sum()-df_waterfall["total_resign"].sum())

# 3. Create the waterfall plot
## For variable 'measure', relative stands for changes of the data (red/green barplot), while total stands for the last data (blue barplot)
fig = go.Figure(go.Waterfall(
    name = "Employee Number", 
    orientation = "v",
    textposition = "outside",
    measure = ["relative" for x in range(len(df_waterfall["changes"]))]+["total"],
    x = df_waterfall["hiring_year"].tolist()+["2021"], 
    y = df_waterfall["changes"].tolist()+[str(all_employees)],
    text = [str(x) if x <=0 else "+"+str(x) for x in df_waterfall["changes"]]+[str(all_employees)],
    connector = {"line":{"color":"rgb(63, 63, 63)", "dash":"solid"}},
    ), 
    layout= layout
)

fig.show()
# Out:
# <div>                            <div id="037aa749-cadb-4f49-9cbc-896360c9881e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("037aa749-cadb-4f49-9cbc-896360c9881e")) {                    Plotly.newPlot(                        "037aa749-cadb-4f49-9cbc-896360c9881e",                        [{"connector":{"line":{"color":"rgb(63, 63, 63)","dash":"solid"}},"measure":["relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","relative","total"],"name":"Employee Number","orientation":"v","text":["+1.0","+2.0","+2.0","+7.0","+8.0","+76.0","+40.0","+40.0","+50.0","+18.0","+2.0","-14.0","-18.0","-7.0","-13.0","194"],"textposition":"outside","type":"waterfall","x
# ...

# %% [markdown]
# ## E. TreeMap Plot

# %%
df_treemap = df.groupby(["Survived","Sex","Pclass"]).agg({"PassengerId":len,"Fare":np.mean}).reset_index()
df_treemap["Survived"] = df_treemap["Survived"].map(lambda x: "Yes" if x == 1 else "No")
df_treemap
# Out:
#    Survived     Sex  Pclass  PassengerId        Fare
# 0        No  female       1            3  110.604167
# 1        No  female       2            6   18.250000
# 2        No  female       3           72   19.773093
# 3        No    male       1           77   62.894910
# 4        No    male       2           91   19.488965
# 5        No    male       3          300   12.204469
# 6       Yes  female       1           91  105.978159
# 7       Yes  female       2           70   22.288989
# 8       Yes  female       3           72   12.464526
# 9       Yes    male       1           45   74.637320
# 10      Yes    male       2           17   21.095100
# 11      Yes    male       3           47   15.579696

# %%
# Treemap using Plotly Express
fig = px.treemap(df_treemap,
                 path=["Survived","Sex","Pclass"], 
                 values='PassengerId', 
                 color = "Fare",
                 color_continuous_scale='YlGnBu',width=1000,height=700,
                 title = "Survivability fact of Titanic Passengers by Gender, Pclass, and Fare"
                 )
fig.show()
# Out:
# <div>                            <div id="8aa6ee1b-166d-40a3-88fb-764bde72134b" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8aa6ee1b-166d-40a3-88fb-764bde72134b")) {                    Plotly.newPlot(                        "8aa6ee1b-166d-40a3-88fb-764bde72134b",                        [{"branchvalues":"total","customdata":[[110.60416666666667],[105.97815934065933],[62.89491038961041],[74.63732],[18.25],[22.288988571428572],[19.488964835164833],[21.095100000000002],[19.77309305555555],[12.464526388888887],[12.20446933333334],[15.579695744680855],[23.024385185185178],[51.938573390557934],[21.960992948717955],[40.82148440366972],[22.11788688524591],[48.39540760233918]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Pa
# ...

# %% [markdown]
# ## F. Sunburst Plot

# %%
df_sunburst = px.data.tips()
df_sunburst.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig = px.sunburst(df_sunburst, 
                  path=['sex', 'day', 'time'], 
                  values='total_bill', 
                  color='time',
                  color_discrete_map={'(?)':'black', 'Lunch':'gold', 'Dinner':'darkblue'})
fig.show()
# Out:
# <div>                            <div id="01d7ed07-acef-4fb6-bd50-f252f32a55f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01d7ed07-acef-4fb6-bd50-f252f32a55f9")) {                    Plotly.newPlot(                        "01d7ed07-acef-4fb6-bd50-f252f32a55f9",                        [{"branchvalues":"total","customdata":[["Dinner"],["Lunch"],["(?)"],["Dinner"],["Dinner"],["Dinner"],["Dinner"],["(?)"],["(?)"],["(?)"],["Lunch"],["Lunch"],["Lunch"],["Dinner"],["Dinner"],["Dinner"],["Dinner"],["Dinner"],["Dinner"],["Lunch"],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>total_bill=%{value}<br>parent=%{parent}<br>id=%{id}<br>time=%{customdata[0]}<extra></extra>","ids":["Female/Fri/Dinner","Male/Thur","Female/Th
# ...

# %%
<center> You can try other beautiful plots:</center>

| Plot Types | Function | Url Link | 
| -- | -- | -- |
| Sankey Plot | Funnel Analysis | https://plotly.com/python/sankey-diagram/ | 
| Parallel Categories Diagram | Funnel Analysis | 
https://plotly.com/python/parallel-categories-diagram/ |
| Maps Related Plot | Geographic Analysis | https://plotly.com/python/maps/ |
| Statistics-related Plot | Statistical Analysis | 
https://plotly.com/python/statistical-charts/ |
| AI and Machine Learning-related Plot | ML Performance Visualization | 
https://plotly.com/python/ai-ml/ |
| Economic-related Plot | Time Series, Funnel, and Indicator Analysis | 
https://plotly.com/python/financial-charts/ |
# Out:
#   File "<ipython-input-38-3693d8416fff>", line 1
#     <center> You can try other beautiful plots:</center>
#     ^
# SyntaxError: invalid syntax
